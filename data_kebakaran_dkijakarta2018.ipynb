# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# prompt: read csv

import pandas as pd
informum_df = pd.read_csv('informum.csv')
informum_df.head()
# Out:
#       tanggal jenis_kejadian_bencana      keterangan_jkb
# 0  2018-02-01           Penyelamatan  Pengendalian Hewan
# 1  2018-02-01              Kebakaran   Bencana Kebakaran
# 2  2018-02-01           Penyelamatan  Pengendalian Hewan
# 3  2018-02-01           Penyelamatan       Pohon Tumbang
# 4  2018-02-01              Kebakaran   Bencana Kebakaran

# %%
# prompt: read csv

import pandas as pd
inforlokpak_df = pd.read_csv('inforlokpak.csv')
inforlokpak_df.head()
# Out:
#         sumber_informasi                      alamat_kejadian  \
# 0      Masyarakat Datang                 Jl. Pisangan Baru II
# 1  Petugas Instansi Lain  Jl. Tol Prumpung/Jagorawi KM. 2/600
# 2      Masyarakat Datang         Stasiun Sudirman, Jl. Kendal
# 3      Masyarakat Datang                      Jl. Kramat Jaya
# 4      Masyarakat Datang                 Jl. Pedongkelan Raya
#
#               kelurahan   kecamatan                          wilayah  \
# 0         Pisangan Baru    Matraman  Kota Administrasi Jakarta Timur
# 1  Cipinang Besar Utara  Jatinegara  Kota Administrasi Jakarta Timur
# 2               Menteng     Menteng  Kota Administrasi Jakarta Pusat
# 3            Tugu Utara        Koja  Kota Administrasi Jakarta Utara
# 4      Cengkareng Timur  Cengkareng  Kota Administrasi Jakarta Barat
#
#    kerugian_jumlah_kk  taksiran_kerugian periode_data
# 0                   0                  0   2018-02-01
# 1                   0          150000000   2018-02-01
# 2                   0                  0   2018-02-01
# 3                   0                  0   2018-02-01
# 4                   1         1215000000   2018-02-01

# %%
informum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3633 entries, 0 to 3632
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tanggal                 3633 non-null   object
#  1   jenis_kejadian_bencana  3633 non-null   object
#  2   keterangan_jkb          3633 non-null   object
# dtypes: object(3)
# memory usage: 85.3+ KB

# %%
informum_df.isna().sum()
# Out:
# tanggal                   0
# jenis_kejadian_bencana    0
# keterangan_jkb            0
# dtype: int64

# %%
print("Jumlah duplikasi: ", informum_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  2419

# %%
# Menampilkan baris-baris yang duplikat
duplicates = informum_df[informum_df.duplicated()]
print(duplicates)
# Out:
#          tanggal jenis_kejadian_bencana      keterangan_jkb
# 2     2018-02-01           Penyelamatan  Pengendalian Hewan
# 4     2018-02-01              Kebakaran   Bencana Kebakaran
# 5     2018-02-01           Penyelamatan  Pengendalian Hewan
# 8     2018-02-02              Kebakaran   Bencana Kebakaran
# 9     2018-02-02           Penyelamatan  Pengendalian Hewan
# ...          ...                    ...                 ...
# 3628  2018-01-09              Kebakaran   Bencana Kebakaran
# 3629  2018-01-03           Penyelamatan  Pengendalian Hewan
# 3630  2018-01-10              Kebakaran   Bencana Kebakaran
# 3631  2018-01-09              Kebakaran   Bencana Kebakaran
# 3632  2018-01-10           Penyelamatan  Pengendalian Hewan
#
# [2419 rows x 3 columns]

# %%
print("Jumlah duplikasi: ", informum_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  2419

# %%
# Menghapus duplikasi, mempertahankan baris pertama
cleaned_df = informum_df.drop_duplicates()

# Menampilkan jumlah duplikasi setelah penghapusan
print("Jumlah duplikasi setelah penghapusan: ", cleaned_df.duplicated().sum())
# Out:
# Jumlah duplikasi setelah penghapusan:  0

# %%
informum_df.describe()
# Out:
#            tanggal jenis_kejadian_bencana     keterangan_jkb
# count         3633                   3633               3633
# unique         335                      3                 12
# top     2018-12-31              Kebakaran  Bencana Kebakaran
# freq            48                   1614               1614

# %%
# Menampilkan jumlah duplikasi setelah penghapusan
print("Jumlah duplikasi setelah penghapusan: ", cleaned_df.duplicated().sum())
# Out:
# Jumlah duplikasi setelah penghapusan:  0

# %%
informum_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3633 entries, 0 to 3632
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tanggal                 3633 non-null   object
#  1   jenis_kejadian_bencana  3633 non-null   object
#  2   keterangan_jkb          3633 non-null   object
# dtypes: object(3)
# memory usage: 85.3+ KB

# %%
informum_df['tanggal'] = pd.to_datetime(informum_df['tanggal'])
print(informum_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3633 entries, 0 to 3632
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tanggal                 3633 non-null   datetime64[ns]
#  1   jenis_kejadian_bencana  3633 non-null   object
#  2   keterangan_jkb          3633 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 85.3+ KB
# None

# %%
informum_df.describe(include="all")
# Out:
#                               tanggal jenis_kejadian_bencana  \
# count                            3633                   3633
# unique                            NaN                      3
# top                               NaN              Kebakaran
# freq                              NaN                   1614
# mean    2018-07-12 07:37:48.208092416                    NaN
# min               2018-01-01 00:00:00                    NaN
# 25%               2018-04-07 00:00:00                    NaN
# 50%               2018-07-21 00:00:00                    NaN
# 75%               2018-10-17 00:00:00                    NaN
# max               2018-12-31 00:00:00                    NaN
#
#            keterangan_jkb
# count                3633
# unique                 12
# top     Bencana Kebakaran
# freq                 1614
# mean                  NaN
# min                   NaN
# 25%                   NaN
# 50%                   NaN
# 75%                   NaN
# max                   NaN

# %%
inforlokpak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3633 entries, 0 to 3632
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sumber_informasi    3633 non-null   object
#  1   alamat_kejadian     3633 non-null   object
#  2   kelurahan           3633 non-null   object
#  3   kecamatan           3633 non-null   object
#  4   wilayah             3633 non-null   object
#  5   kerugian_jumlah_kk  3633 non-null   int64
#  6   taksiran_kerugian   3633 non-null   int64
#  7   periode_data        3633 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 227.2+ KB

# %%
import pandas as pd

# Mengonversi kolom ke tipe data yang sesuai
inforlokpak_df['kerugian_jumlah_kk'] = inforlokpak_df['kerugian_jumlah_kk'].astype('int64')
inforlokpak_df['taksiran_kerugian'] = inforlokpak_df['taksiran_kerugian'].astype('int64')
inforlokpak_df['periode_data'] = pd.to_datetime(inforlokpak_df['periode_data'])

# Menampilkan info DataFrame setelah konversi
inforlokpak_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3633 entries, 0 to 3632
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sumber_informasi    3633 non-null   object
#  1   alamat_kejadian     3633 non-null   object
#  2   kelurahan           3633 non-null   object
#  3   kecamatan           3633 non-null   object
#  4   wilayah             3633 non-null   object
#  5   kerugian_jumlah_kk  3633 non-null   int64
#  6   taksiran_kerugian   3633 non-null   int64
#  7   periode_data        3633 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(5)
# memory usage: 227.2+ KB

# %%
inforlokpak_df.isna().sum()
# Out:
# sumber_informasi      0
# alamat_kejadian       0
# kelurahan             0
# kecamatan             0
# wilayah               0
# kerugian_jumlah_kk    0
# taksiran_kerugian     0
# periode_data          0
# dtype: int64

# %%
print("Jumlah duplikasi: ", inforlokpak_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  156

# %%
inforlokpak_df.describe()
# Out:
#        kerugian_jumlah_kk  taksiran_kerugian                   periode_data
# count         3633.000000       3.633000e+03                           3633
# mean             0.748417       6.319675e+07  2018-06-27 08:18:13.971924224
# min              0.000000       0.000000e+00            2018-01-01 00:00:00
# 25%              0.000000       0.000000e+00            2018-04-01 00:00:00
# 50%              0.000000       0.000000e+00            2018-07-01 00:00:00
# 75%              0.000000       2.500000e+05            2018-10-01 00:00:00
# max            600.000000       3.000000e+10            2018-12-01 00:00:00
# std             12.768763       6.094281e+08                            NaN

# %%
# Menghapus duplikasi, mempertahankan baris pertama
cleaned_df = inforlokpak_df.drop_duplicates()

# Menampilkan jumlah duplikasi setelah penghapusan
print("Jumlah duplikasi setelah penghapusan: ", cleaned_df.duplicated().sum())
# Out:
# Jumlah duplikasi setelah penghapusan:  0

# %%
inforlokpak_df.describe()
# Out:
#        kerugian_jumlah_kk  taksiran_kerugian                   periode_data
# count         3633.000000       3.633000e+03                           3633
# mean             0.748417       6.319675e+07  2018-06-27 08:18:13.971924224
# min              0.000000       0.000000e+00            2018-01-01 00:00:00
# 25%              0.000000       0.000000e+00            2018-04-01 00:00:00
# 50%              0.000000       0.000000e+00            2018-07-01 00:00:00
# 75%              0.000000       2.500000e+05            2018-10-01 00:00:00
# max            600.000000       3.000000e+10            2018-12-01 00:00:00
# std             12.768763       6.094281e+08                            NaN

# %%
print(inforlokpak_df[['kerugian_jumlah_kk', 'taksiran_kerugian']].isna().sum())
# Out:
# kerugian_jumlah_kk    0
# taksiran_kerugian     0
# dtype: int64

# %%
print(inforlokpak_df[['kerugian_jumlah_kk', 'taksiran_kerugian']].describe(include='all'))
# Out:
#        kerugian_jumlah_kk  taksiran_kerugian
# count         3633.000000       3.633000e+03
# mean             0.748417       6.319675e+07
# std             12.768763       6.094281e+08
# min              0.000000       0.000000e+00
# 25%              0.000000       0.000000e+00
# 50%              0.000000       0.000000e+00
# 75%              0.000000       2.500000e+05
# max            600.000000       3.000000e+10

# %%
extreme_values_kerugian = informum_df[inforlokpak_df['kerugian_jumlah_kk'] > 100]
extreme_values_taksiran = informum_df[inforlokpak_df['taksiran_kerugian'] > 1000000]
print(extreme_values_kerugian)
print(extreme_values_taksiran)
# Out:
#         tanggal jenis_kejadian_bencana     keterangan_jkb
# 3117 2018-04-21              Kebakaran  Bencana Kebakaran
# 3245 2018-03-29              Kebakaran  Bencana Kebakaran
# 3563 2018-01-27              Kebakaran  Bencana Kebakaran
#         tanggal jenis_kejadian_bencana     keterangan_jkb
# 1    2018-02-01              Kebakaran  Bencana Kebakaran
# 4    2018-02-01              Kebakaran  Bencana Kebakaran
# 6    2018-02-02              Kebakaran  Bencana Kebakaran
# 8    2018-02-02              Kebakaran  Bencana Kebakaran
# 10   2018-02-03              Kebakaran  Bencana Kebakaran
# ...         ...                    ...                ...
# 3618 2018-01-08              Kebakaran  Bencana Kebakaran
# 3624 2018-01-09              Kebakaran  Bencana Kebakaran
# 3627 2018-01-09              Kebakaran  Bencana Kebakaran
# 3628 2018-01-09              Kebakaran  Bencana Kebakaran
# 3631 2018-01-09              Kebakaran  Bencana Kebakaran
#
# [810 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Histogram
inforlokpak_df[['kerugian_jumlah_kk', 'taksiran_kerugian']].hist(bins=50, figsize=(12, 6))
plt.show()

# Boxplot
inforlokpak_df[['kerugian_jumlah_kk', 'taksiran_kerugian']].boxplot(figsize=(12, 6))
plt.show()

# %%
import numpy as np

# Menggunakan transformasi logaritma (jika relevan)
inforlokpak_df['log_taksiran_kerugian'] = np.log1p(inforlokpak_df['taksiran_kerugian'])
inforlokpak_df[['log_taksiran_kerugian']].describe()
# Out:
#        log_taksiran_kerugian
# count            3633.000000
# mean                4.384077
# std                 7.539136
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                12.429220
# max                24.124463

# %%
# Memeriksa nilai-nilai yang tidak wajar
invalid_entries = inforlokpak_df[(inforlokpak_df['kerugian_jumlah_kk'] < 0) | (inforlokpak_df['taksiran_kerugian'] < 0)]
print(invalid_entries)
# Out:
# Empty DataFrame
# Columns: [sumber_informasi, alamat_kejadian, kelurahan, kecamatan, wilayah, kerugian_jumlah_kk, taksiran_kerugian, periode_data, log_taksiran_kerugian]
# Index: []

# %%
inforlokpak_df.describe()
# Out:
#        kerugian_jumlah_kk  taksiran_kerugian                   periode_data  \
# count         3633.000000       3.633000e+03                           3633
# mean             0.748417       6.319675e+07  2018-06-27 08:18:13.971924224
# min              0.000000       0.000000e+00            2018-01-01 00:00:00
# 25%              0.000000       0.000000e+00            2018-04-01 00:00:00
# 50%              0.000000       0.000000e+00            2018-07-01 00:00:00
# 75%              0.000000       2.500000e+05            2018-10-01 00:00:00
# max            600.000000       3.000000e+10            2018-12-01 00:00:00
# std             12.768763       6.094281e+08                            NaN
#
#        log_taksiran_kerugian
# count            3633.000000
# mean                4.384077
# min                 0.000000
# 25%                 0.000000
# 50%                 0.000000
# 75%                12.429220
# max                24.124463
# std                 7.539136

# %%
inforlokpak_df.kerugian_jumlah_kk.value_counts()
# Out:
# kerugian_jumlah_kk
# 0      3302
# 1       200
# 2        29
# 3        27
# 6        14
# 5         9
# 10        8
# 4         6
# 8         4
# 32        3
# 15        3
# 20        3
# 30        2
# 12        2
# 11        2
# 70        2
# 25        2
# 60        1
# 24        1
# 400       1
# 166       1
# 36        1
# 97        1
# 19        1
# 17        1
# 9         1
# 18        1
# 85        1
# 40        1
# 21        1
# 26        1
# 600       1
# Name: count, dtype: int64

# %%
inforlokpak_df.fillna(value="0", inplace=True)

# %%
inforlokpak_df[inforlokpak_df.kerugian_jumlah_kk == inforlokpak_df.kerugian_jumlah_kk.max()]
# Out:
#        sumber_informasi                                    alamat_kejadian  \
# 3563  Masyarakat Datang  Jl. Keutamaan Dalam rt. 7,8,9,10,11,12,13,14,1...
#
#      kelurahan  kecamatan                          wilayah  \
# 3563    Krukut  Tamansari  Kota Administrasi Jakarta Barat
#
#       kerugian_jumlah_kk  taksiran_kerugian periode_data  \
# 3563                 600         4500000000   2018-01-01
#
#       log_taksiran_kerugian
# 3563              22.227343

# %%
informum_df.describe(include="all")
# Out:
#                               tanggal jenis_kejadian_bencana  \
# count                            3633                   3633
# unique                            NaN                      3
# top                               NaN              Kebakaran
# freq                              NaN                   1614
# mean    2018-07-12 07:37:48.208092416                    NaN
# min               2018-01-01 00:00:00                    NaN
# 25%               2018-04-07 00:00:00                    NaN
# 50%               2018-07-21 00:00:00                    NaN
# 75%               2018-10-17 00:00:00                    NaN
# max               2018-12-31 00:00:00                    NaN
#
#            keterangan_jkb
# count                3633
# unique                 12
# top     Bencana Kebakaran
# freq                 1614
# mean                  NaN
# min                   NaN
# 25%                   NaN
# 50%                   NaN
# 75%                   NaN
# max                   NaN

# %%
inforlokpak_df.describe(include="all")
# Out:
#          sumber_informasi    alamat_kejadian kelurahan    kecamatan  \
# count                3633               3633      3633         3633
# unique                  6               3227       401           52
# top     Masyarakat Datang  Jl. Benyamin Sueb    Gelora  Tanah Abang
# freq                 1280                 11       159          253
# mean                  NaN                NaN       NaN          NaN
# min                   NaN                NaN       NaN          NaN
# 25%                   NaN                NaN       NaN          NaN
# 50%                   NaN                NaN       NaN          NaN
# 75%                   NaN                NaN       NaN          NaN
# max                   NaN                NaN       NaN          NaN
# std                   NaN                NaN       NaN          NaN
#
#                                 wilayah  kerugian_jumlah_kk  \
# count                              3633         3633.000000
# unique                               11                 NaN
# top     Kota Administrasi Jakarta Pusat                 NaN
# freq                                859                 NaN
# mean                                NaN            0.748417
# min                                 NaN            0.000000
# 25%                                 NaN            0.000000
# 50%                                 NaN            0.000000
# 75%                                 NaN            0.000000
# max                                 NaN          600.000000
# std                                 NaN           12.768763
#
#         taksiran_kerugian                   periode_data  \
# count        3.633000e+03                           3633
# unique                NaN                            NaN
# top                   NaN                            NaN
# freq                  NaN                            NaN
# mean         6.319675e+07  2018-06-27 08:18:13.971924224
# min          0.000000e+00            2018-01-01 00:00:00
# 25%          0.000000e+00            2018-04-01 00:00:00
# 50%          0.000000e+00            2018-07-01 00:00:00
# 75%          2.500000e+05            2018-10-01 00:00:00
# max          3.000000e+10            2018-12-01 00:00:00
# std          6.094281e+08                            NaN
#
#         log_taksiran_kerugian
# count             3633.000000
# unique                    NaN
# top                       NaN
# freq                      NaN
# mean                 4.384077
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                 12.429220
# max                 24.124463
# std                  7.539136

# %%
informum_df.groupby(by="tanggal").agg({
    "jenis_kejadian_bencana": "first",  # Replace with an appropriate aggregation function
    "keterangan_jkb": "first"  # Replace with an appropriate aggregation function
})
# Out:
#            jenis_kejadian_bencana      keterangan_jkb
# tanggal
# 2018-01-01              Kebakaran   Bencana Kebakaran
# 2018-01-02              Kebakaran   Bencana Kebakaran
# 2018-01-03           Penyelamatan  Pengendalian Hewan
# 2018-01-04              Kebakaran   Bencana Kebakaran
# 2018-01-05           Penyelamatan       Pohon Tumbang
# ...                           ...                 ...
# 2018-12-27              Kebakaran   Bencana Kebakaran
# 2018-12-28              Kebakaran   Bencana Kebakaran
# 2018-12-29           Penyelamatan       Pohon Tumbang
# 2018-12-30              Kebakaran   Bencana Kebakaran
# 2018-12-31              Kebakaran   Bencana Kebakaran
#
# [335 rows x 2 columns]

# %%
# Kelompokkan berdasarkan 'tanggal' dan hitung kejadian 'jenis_kejadian_bencana'
result = informum_df.groupby(by="tanggal")['jenis_kejadian_bencana'].count()

# Temukan tanggal dengan jumlah terbanyak
tanggal_terbanyak = result.idxmax()
print("Tanggal dengan kejadian bencana terbanyak:", tanggal_terbanyak)

# Ekstrak bulan dari tanggal terbanyak
import pandas as pd
bulan_terbanyak = pd.to_datetime(tanggal_terbanyak).month_name()
print("Bulan dengan kejadian bencana terbanyak:", bulan_terbanyak)
# Out:
# Tanggal dengan kejadian bencana terbanyak: 2018-12-31 00:00:00
# Bulan dengan kejadian bencana terbanyak: December

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Kelompokkan berdasarkan bulan dan hitung jumlah kejadian bencana
informum_df['bulan'] = pd.to_datetime(informum_df['tanggal']).dt.to_period('M')
monthly_counts = informum_df.groupby('bulan')['jenis_kejadian_bencana'].count()

# Temukan 5 bulan dengan jumlah terbanyak
top_10_months = monthly_counts.nlargest(10)
print("5 Bulan dengan kejadian bencana terbanyak:\n", top_10_months)

# Visualisasikan 5 bulan dengan kejadian bencana terbanyak
plt.figure(figsize=(10, 6))
sns.barplot(x=top_10_months.index.astype(str), y=top_10_months.values, palette='viridis')
plt.title('5 Bulan dengan Kejadian Bencana Terbanyak')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Kejadian Bencana')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# 5 Bulan dengan kejadian bencana terbanyak:
#  bulan
# 2018-08    528
# 2018-10    446
# 2018-12    406
# 2018-02    334
# 2018-11    327
# 2018-07    317
# 2018-03    271
# 2018-05    267
# 2018-06    252
# 2018-01    243
# Freq: M, Name: jenis_kejadian_bencana, dtype: int64
# <ipython-input-148-6f4ee2bc515a>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_10_months.index.astype(str), y=top_10_months.values, palette='viridis')

# %%
# Hitung kejadian setiap jenis bencana
jenis_bencana_counts = informum_df['jenis_kejadian_bencana'].value_counts()

# Tampilkan jenis bencana yang paling sering terjadi
print("Jenis-jenis kejadian bencana yang paling sering terjadi:")
print(jenis_bencana_counts)
# Out:
# Jenis-jenis kejadian bencana yang paling sering terjadi:
# jenis_kejadian_bencana
# Kebakaran          1614
# Penyelamatan       1131
# Bantuan Operasi     888
# Name: count, dtype: int64

# %%
import pandas as pd

# Ekstrak tahun dari kolom 'tanggal'
informum_df['tahun'] = pd.to_datetime(informum_df['tanggal']).dt.year

# Hitung jumlah tahun yang unik
jumlah_tahun = informum_df['tahun'].nunique()

print("Jumlah tahun dalam kolom 'tanggal':", jumlah_tahun)
# Out:
# Jumlah tahun dalam kolom 'tanggal': 1

# %%
# Tampilkan tahun-tahun yang unik
tahun_unik = informum_df['tahun'].unique()
print("Tahun-tahun yang terdapat dalam kolom 'tanggal':", tahun_unik)
# Out:
# Tahun-tahun yang terdapat dalam kolom 'tanggal': [2018]

# %%
inforlokpak_df.head()
# Out:
#         sumber_informasi                      alamat_kejadian  \
# 0      Masyarakat Datang                 Jl. Pisangan Baru II
# 1  Petugas Instansi Lain  Jl. Tol Prumpung/Jagorawi KM. 2/600
# 2      Masyarakat Datang         Stasiun Sudirman, Jl. Kendal
# 3      Masyarakat Datang                      Jl. Kramat Jaya
# 4      Masyarakat Datang                 Jl. Pedongkelan Raya
#
#               kelurahan   kecamatan                          wilayah  \
# 0         Pisangan Baru    Matraman  Kota Administrasi Jakarta Timur
# 1  Cipinang Besar Utara  Jatinegara  Kota Administrasi Jakarta Timur
# 2               Menteng     Menteng  Kota Administrasi Jakarta Pusat
# 3            Tugu Utara        Koja  Kota Administrasi Jakarta Utara
# 4      Cengkareng Timur  Cengkareng  Kota Administrasi Jakarta Barat
#
#    kerugian_jumlah_kk  taksiran_kerugian periode_data  log_taksiran_kerugian
# 0                   0                  0   2018-02-01               0.000000
# 1                   0          150000000   2018-02-01              18.826146
# 2                   0                  0   2018-02-01               0.000000
# 3                   0                  0   2018-02-01               0.000000
# 4                   1         1215000000   2018-02-01              20.918010

# %%
# Distribusi taksiran kerugian
plt.figure(figsize=(10, 6))
sns.histplot(inforlokpak_df['taksiran_kerugian'], bins=30, kde=True, color='blue')
plt.title('Distribusi Taksiran Kerugian')
plt.xlabel('Taksiran Kerugian')
plt.ylabel('Frekuensi')
plt.show()

# Distribusi kerugian jumlah KK
plt.figure(figsize=(10, 6))
sns.histplot(inforlokpak_df['kerugian_jumlah_kk'], bins=30, kde=True, color='red')
plt.title('Distribusi Kerugian Jumlah KK')
plt.xlabel('Jumlah KK')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Jumlah kejadian kebakaran per wilayah
plt.figure(figsize=(12, 8))
sns.countplot(y='wilayah', data=inforlokpak_df, palette='viridis')
plt.title('Jumlah Kejadian Kebakaran per Wilayah')
plt.xlabel('Jumlah Kejadian')
plt.ylabel('Wilayah')
plt.show()
# Out:
# <ipython-input-153-3a198727952d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='wilayah', data=inforlokpak_df, palette='viridis')

# %%
# Ekstrak bulan dari periode_data
inforlokpak_df['periode_data'] = pd.to_datetime(inforlokpak_df['periode_data'])
inforlokpak_df['bulan'] = inforlokpak_df['periode_data'].dt.to_period('M')

# Jumlah kejadian kebakaran per bulan
monthly_counts = inforlokpak_df['bulan'].value_counts().sort_index()

plt.figure(figsize=(12, 8))
sns.barplot(x=monthly_counts.index.astype(str), y=monthly_counts.values)
plt.title('Jumlah Kejadian Kebakaran per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Kejadian')
plt.xticks(rotation=45)
plt.show()

# %%
# Jumlah kejadian kebakaran per kecamatan
plt.figure(figsize=(12, 8))
sns.countplot(y='kecamatan', data=inforlokpak_df, palette='magma')
plt.title('Jumlah Kejadian Kebakaran per Kecamatan')
plt.xlabel('Jumlah Kejadian')
plt.ylabel('Kecamatan')
plt.show()
# Out:
# <ipython-input-162-b0e59d7781fc>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='kecamatan', data=inforlokpak_df, palette='magma')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Misalkan dataset Anda sudah dimuat dalam DataFrame bernama inforlokpak_df
# Hitung jumlah kejadian kebakaran per kecamatan
kecamatan_counts = inforlokpak_df['kecamatan'].value_counts()

# Ambil 10 kecamatan dengan jumlah kejadian terbanyak
top_10_kecamatan = kecamatan_counts.head(10)

# Visualisasikan 10 kecamatan dengan jumlah kejadian kebakaran terbanyak
plt.figure(figsize=(12, 8))
sns.barplot(y=top_10_kecamatan.index, x=top_10_kecamatan.values, palette='magma')
plt.title('10 Kecamatan dengan Jumlah Kejadian Kebakaran Terbanyak')
plt.xlabel('Jumlah Kejadian')
plt.ylabel('Kecamatan')
plt.show()
# Out:
# <ipython-input-163-0707b748543f>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=top_10_kecamatan.index, x=top_10_kecamatan.values, palette='magma')

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='kerugian_jumlah_kk', y='taksiran_kerugian', data=inforlokpak_df, alpha=0.6)
plt.title('Hubungan antara Kerugian Jumlah KK dan Taksiran Kerugian')
plt.xlabel('Kerugian Jumlah KK')
plt.ylabel('Taksiran Kerugian')
plt.show()

# %%
# Boxplot untuk mengecek outliers pada taksiran kerugian
plt.figure(figsize=(10, 6))
sns.boxplot(x=inforlokpak_df['taksiran_kerugian'])
plt.title('Boxplot Taksiran Kerugian')
plt.xlabel('Taksiran Kerugian')
plt.show()

# %%
all_df = pd.merge(
    left=informum_df,
    right=inforlokpak_df,
    how="left",
    left_on="tanggal",       # Ganti dengan kolom yang relevan
    right_on="periode_data"  # Ganti dengan kolom yang relevan
)
all_df.head()
# Out:
#      tanggal jenis_kejadian_bencana      keterangan_jkb  tahun  bulan_x  \
# 0 2018-02-01           Penyelamatan  Pengendalian Hewan   2018  2018-02
# 1 2018-02-01           Penyelamatan  Pengendalian Hewan   2018  2018-02
# 2 2018-02-01           Penyelamatan  Pengendalian Hewan   2018  2018-02
# 3 2018-02-01           Penyelamatan  Pengendalian Hewan   2018  2018-02
# 4 2018-02-01           Penyelamatan  Pengendalian Hewan   2018  2018-02
#
#         sumber_informasi                      alamat_kejadian  \
# 0      Masyarakat Datang                 Jl. Pisangan Baru II
# 1  Petugas Instansi Lain  Jl. Tol Prumpung/Jagorawi KM. 2/600
# 2      Masyarakat Datang         Stasiun Sudirman, Jl. Kendal
# 3      Masyarakat Datang                      Jl. Kramat Jaya
# 4      Masyarakat Datang                 Jl. Pedongkelan Raya
#
#               kelurahan   kecamatan                          wilayah  \
# 0         Pisangan Baru    Matraman  Kota Administrasi Jakarta Timur
# 1  Cipinang Besar Utara  Jatinegara  Kota Administrasi Jakarta Timur
# 2               Menteng     Menteng  Kota Administrasi Jakarta Pusat
# 3            Tugu Utara        Koja  Kota Administrasi Jakarta Utara
# 4      Cengkareng Timur  Cengkareng  Kota Administrasi Jakarta Barat
#
#    kerugian_jumlah_kk  taksiran_kerugian periode_data  log_taksiran_kerugian  \
# 0                 0.0       0.000000e+00   2018-02-01               0.000000
# 1                 0.0       1.500000e+08   2018-02-01              18.826146
# 2                 0.0       0.000000e+00   2018-02-01               0.000000
# 3                 0.0       0.000000e+00   2018-02-01               0.000000
# 4                 1.0       1.215000e+09   2018-02-01              20.918010
#
#    bulan_y
# 0  2018-02
# 1  2018-02
# 2  2018-02
# 3  2018-02
# 4  2018-02

# %%
# Menghapus kolom duplikat yang tidak diperlukan
all_df = all_df.drop(columns=['bulan_x', 'bulan_y'])  # Ganti dengan nama kolom yang tidak perlu

# %%
all_df.head()
# Out:
#      tanggal jenis_kejadian_bencana      keterangan_jkb  tahun  \
# 0 2018-02-01           Penyelamatan  Pengendalian Hewan   2018
# 1 2018-02-01           Penyelamatan  Pengendalian Hewan   2018
# 2 2018-02-01           Penyelamatan  Pengendalian Hewan   2018
# 3 2018-02-01           Penyelamatan  Pengendalian Hewan   2018
# 4 2018-02-01           Penyelamatan  Pengendalian Hewan   2018
#
#         sumber_informasi                      alamat_kejadian  \
# 0      Masyarakat Datang                 Jl. Pisangan Baru II
# 1  Petugas Instansi Lain  Jl. Tol Prumpung/Jagorawi KM. 2/600
# 2      Masyarakat Datang         Stasiun Sudirman, Jl. Kendal
# 3      Masyarakat Datang                      Jl. Kramat Jaya
# 4      Masyarakat Datang                 Jl. Pedongkelan Raya
#
#               kelurahan   kecamatan                          wilayah  \
# 0         Pisangan Baru    Matraman  Kota Administrasi Jakarta Timur
# 1  Cipinang Besar Utara  Jatinegara  Kota Administrasi Jakarta Timur
# 2               Menteng     Menteng  Kota Administrasi Jakarta Pusat
# 3            Tugu Utara        Koja  Kota Administrasi Jakarta Utara
# 4      Cengkareng Timur  Cengkareng  Kota Administrasi Jakarta Barat
#
#    kerugian_jumlah_kk  taksiran_kerugian periode_data  log_taksiran_kerugian
# 0                 0.0       0.000000e+00   2018-02-01               0.000000
# 1                 0.0       1.500000e+08   2018-02-01              18.826146
# 2                 0.0       0.000000e+00   2018-02-01               0.000000
# 3                 0.0       0.000000e+00   2018-02-01               0.000000
# 4                 1.0       1.215000e+09   2018-02-01              20.918010

# %%
# Deskripsi umum dari DataFrame
all_df.info()
all_df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38403 entries, 0 to 38402
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tanggal                 38403 non-null  datetime64[ns]
#  1   jenis_kejadian_bencana  38403 non-null  object
#  2   keterangan_jkb          38403 non-null  object
#  3   tahun                   38403 non-null  int32
#  4   sumber_informasi        34874 non-null  object
#  5   alamat_kejadian         34874 non-null  object
#  6   kelurahan               34874 non-null  object
#  7   kecamatan               34874 non-null  object
#  8   wilayah                 34874 non-null  object
#  9   kerugian_jumlah_kk      34874 non-null  float64
#  10  taksiran_kerugian       34874 non-null  float64
#  11  periode_data            34874 non-null  datetime64[ns]
#  12  log_taksiran_kerugian   34874 non-null  float64
# dtypes: datetime64[ns](2), float64(3), int32(1), object(7)
# memory usage: 3.7+ MB
#                               tanggal jenis_kejadian_bencana  \
# count                           38403                  38403
# unique                            NaN                      3
# top                               NaN              Kebakaran
# freq                              NaN                  20678
# mean    2018-07-03 10:58:29.163346688                    NaN
# min               2018-01-01 00:00:00                    NaN
# 25%               2018-04-01 00:00:00                    NaN
# 50%               2018-08-01 00:00:00                    NaN
# 75%               2018-10-01 00:00:00                    NaN
# max               2018-12-31 00:00:00                    NaN
# std                               NaN                    NaN
#
#            keterangan_jkb    tahun   sumber_informasi    alamat_kejadian  \
# count               38403  38403.0              34874              34874
# unique                 12      NaN                  6               3227
# top     Bencana Kebakaran      NaN  Masyarakat Datang  Jl. Benyamin Sueb
# freq                20678      NaN              12046                119
# mean                  NaN   2018.0                NaN                NaN
# min                   NaN   2018.0                NaN                NaN
# 25%                   NaN   2018.0                NaN                NaN
# 50%                   NaN   2018.0                NaN                NaN
# 75%                   NaN   2018.0                NaN                NaN
# max                   NaN   2018.0                NaN                NaN
# std                   NaN      0.0                NaN                NaN
#
#        kelurahan    kecamatan                          wilayah  \
# count      34874        34874                            34874
# unique       401           52                               11
# top       Gelora  Tanah Abang  Kota Administrasi Jakarta Pusat
# freq        1697         2588                             8326
# mean         NaN          NaN                              NaN
# min          NaN          NaN                              NaN
# 25%          NaN          NaN                              NaN
# 50%          NaN          NaN                              NaN
# 75%          NaN          NaN                              NaN
# max          NaN          NaN                              NaN
# std          NaN          NaN                              NaN
#
#         kerugian_jumlah_kk  taksiran_kerugian                   periode_data  \
# count         34874.000000       3.487400e+04                          34874
# unique                 NaN                NaN                            NaN
# top                    NaN                NaN                            NaN
# freq                   NaN                NaN                            NaN
# mean              0.770631       6.397443e+07  2018-07-02 11:16:13.860182272
# min               0.000000       0.000000e+00            2018-01-01 00:00:00
# 25%               0.000000       0.000000e+00            2018-04-01 00:00:00
# 50%               0.000000       0.000000e+00            2018-08-01 00:00:00
# 75%               0.000000       2.000000e+05            2018-10-01 00:00:00
# max             600.000000       3.000000e+10            2018-12-01 00:00:00
# std              13.801004       6.013468e+08                            NaN
#
#         log_taksiran_kerugian
# count            34874.000000
# unique                    NaN
# top                       NaN
# freq                      NaN
# mean                 4.363149
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                 12.206078
# max                 24.124463
# std                  7.532939

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.countplot(y='jenis_kejadian_bencana', data=all_df, palette='viridis')
plt.title('Distribusi Jenis Kejadian Bencana')
plt.xlabel('Jumlah Kejadian')
plt.ylabel('Jenis Kejadian Bencana')
plt.show()
# Out:
# <ipython-input-172-47ec8de3cf76>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='jenis_kejadian_bencana', data=all_df, palette='viridis')

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='kerugian_jumlah_kk', y='wilayah', data=all_df, palette='magma')
plt.title('Kerugian Berdasarkan Wilayah')
plt.xlabel('Jumlah Kerugian')
plt.ylabel('Wilayah')
plt.show()
# Out:
# <ipython-input-173-3b9cc8125e33>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='kerugian_jumlah_kk', y='wilayah', data=all_df, palette='magma')

# %%
# Pastikan kolom tanggal dalam format datetime
all_df['tanggal'] = pd.to_datetime(all_df['tanggal'])

# Ekstrak bulan dan tahun dari kolom tanggal
all_df['bulan'] = all_df['tanggal'].dt.to_period('M').astype(str)

# Hitung total kerugian per bulan
kerugian_per_bulan = all_df.groupby('bulan')['kerugian_jumlah_kk'].sum().reset_index()

# Urutkan berdasarkan kerugian terbanyak
kerugian_per_bulan = kerugian_per_bulan.sort_values(by='kerugian_jumlah_kk', ascending=False)

plt.figure(figsize=(12, 6))
sns.lineplot(x='bulan', y='kerugian_jumlah_kk', data=kerugian_per_bulan, marker='o', color='blue')
plt.title('Tren Kerugian dari Bulan ke Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Kerugian')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Ambil 5 bulan dengan kerugian terbanyak
top_5_bulan = kerugian_per_bulan.head(5)

plt.figure(figsize=(12, 6))
sns.barplot(x='kerugian_jumlah_kk', y='bulan', data=top_5_bulan, palette='magma')
plt.title('Top 5 Bulan dengan Kerugian Terbanyak')
plt.xlabel('Jumlah Kerugian')
plt.ylabel('Bulan')
plt.show()
# Out:
# <ipython-input-180-2077cdc9b581>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='kerugian_jumlah_kk', y='bulan', data=top_5_bulan, palette='magma')

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x='kerugian_jumlah_kk', y='jenis_kejadian_bencana', data=all_df, palette='cividis')
plt.title('Kerugian Berdasarkan Jenis Kejadian Bencana')
plt.xlabel('Jumlah Kerugian')
plt.ylabel('Jenis Kejadian Bencana')
plt.show()
# Out:
# <ipython-input-181-ea6682b1f975>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='kerugian_jumlah_kk', y='jenis_kejadian_bencana', data=all_df, palette='cividis')

# %%
plt.figure(figsize=(12, 6))
sns.histplot(all_df['log_taksiran_kerugian'], kde=True, color='teal')
plt.title('Distribusi Log Taksiran Kerugian')
plt.xlabel('Log Taksiran Kerugian')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Ekstrak bulan dari tanggal
all_df['bulan'] = pd.to_datetime(all_df['tanggal']).dt.month_name()

plt.figure(figsize=(12, 6))
sns.countplot(x='bulan', data=all_df, palette='Set2')
plt.title('Jumlah Kejadian Kebakaran per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Kejadian')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-183-d812bf22ddcd>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='bulan', data=all_df, palette='Set2')

# %%
all_df.to_csv("readytouse_alldata.csv", index=False)
